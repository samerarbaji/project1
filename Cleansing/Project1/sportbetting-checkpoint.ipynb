# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
Sibyl_vs_Bookies = "Resources/Sibyl_vs_Bookies_US_Football_top5.csv"


Sibyl_vs_Bookies_df = pd.read_csv(Sibyl_vs_Bookies)
Sibyl_vs_Bookies_df
# Out:
#       ID          League        Date   Time                    Matchup_US_P  \
# 0      0         ligue-1  2016-08-12  19:30               Guingamp @ Monaco
# 1      1  premier-league  2016-08-13  15:00             Tottenham @ Everton
# 2      2  premier-league  2016-08-13  15:00          Swansea City @ Burnley
# 3      3  premier-league  2016-08-13  15:00  West Bromwich @ Crystal Palace
# 4      4  premier-league  2016-08-13  15:00           Watford @ Southampton
# ..   ...             ...         ...    ...                             ...
# 328  328         serie-a  2016-10-16  14:00          Cagliari @ Inter Milan
# 329  329         serie-a  2016-10-16  14:00                  Empoli @ Genoa
# 330  330         serie-a  2016-10-16  14:00              Crotone @ Sassuolo
# 331  331         serie-a  2016-10-16  19:45               AC Milan @ Chievo
# 332  332         serie-a  2016-10-17  19:45                Torino @ Palermo
#
#       Visitor_Team       Home_Team  Visitor_Odd  Draw_Odd  Home_Odd  \
# 0         Guingamp          Monaco         5.50      3.70      1.69
# 1        Tottenham         Everton         2.19      3.40      3.55
# 2     Swansea City         Burnley         2.82      3.15      2.77
# 3    West Bromwich  Crystal Palace         3.91      3.17      2.17
# 4          Watford     Southampton         4.86      3.71      1.79
# ..             ...             ...          ...       ...       ...
# 328       Cagliari     Inter Milan         9.49      5.14      1.35
# 329         Empoli           Genoa         4.95      3.50      1.81
# 330        Crotone        Sassuolo         6.73      4.15      1.54
# 331       AC Milan          Chievo         2.55      3.07      3.11
# 332         Torino         Palermo         1.92      3.46      4.32
#
#      Bookies_choice           Sibyl  Confidence Divergence_Y/N  Visi_Team_PTS  \
# 0            Monaco          Monaco       0.559              N              2
# 1         Tottenham         Everton       0.385              Y              1
# 2           Burnley         Burnley       0.577              N              1
# 3    Crystal Palace  Crystal Palace       0.385              N              1
# 4       Southampton     Southampton       0.427              N              1
# ..              ...             ...         ...            ...            ...
# 328     Inter Milan     Inter Milan       0.508              N              2
# 329           Genoa           Genoa       0.542              N              0
# 330        Sassuolo        Sassuolo       0.553              N              1
# 331        AC Milan        AC Milan       0.412              N              3
# 332          Torino          Torino       0.550              N              4
#
#      Home_Team_PTS    True_Result  Winner_Odd
# 0                2           Draw        3.70
# 1                1           Draw        3.40
# 2                0   Swansea City        2.82
# 3                0  West Bromwich        3.91
# 4                1           Draw        3.71
# ..             ...            ...         ...
# 328              1       Cagliari        9.49
# 329              0           Draw        3.50
# 330              2       Sassuolo        1.54
# 331              1       AC Milan        2.55
# 332              1         Torino        1.92
#
# [333 rows x 18 columns]

# %%
Sibyl_vs_Bookies_df["League"].unique()
# Out:
# array(['ligue-1', 'premier-league', 'laliga', 'serie-a', 'bundesliga'],
#       dtype=object)

# %%
Sibyl_vs_Bookies_df["League"].value_counts()
# Out:
# ligue-1           78
# serie-a           76
# premier-league    68
# laliga            68
# bundesliga        43
# Name: League, dtype: int64

# %%
reduced_df = Sibyl_vs_Bookies_df[["League", "Visitor_Team", "Home_Team", "Visitor_Odd",
                       "Draw_Odd", "Home_Odd", "Bookies_choice", "Sibyl", "Confidence", "Divergence_Y/N", "True_Result", "Winner_Odd"]]
reduced_df
# Out:
#              League   Visitor_Team       Home_Team  Visitor_Odd  Draw_Odd  \
# 0           ligue-1       Guingamp          Monaco         5.50      3.70
# 1    premier-league      Tottenham         Everton         2.19      3.40
# 2    premier-league   Swansea City         Burnley         2.82      3.15
# 3    premier-league  West Bromwich  Crystal Palace         3.91      3.17
# 4    premier-league        Watford     Southampton         4.86      3.71
# ..              ...            ...             ...          ...       ...
# 328         serie-a       Cagliari     Inter Milan         9.49      5.14
# 329         serie-a         Empoli           Genoa         4.95      3.50
# 330         serie-a        Crotone        Sassuolo         6.73      4.15
# 331         serie-a       AC Milan          Chievo         2.55      3.07
# 332         serie-a         Torino         Palermo         1.92      3.46
#
#      Home_Odd  Bookies_choice           Sibyl  Confidence Divergence_Y/N  \
# 0        1.69          Monaco          Monaco       0.559              N
# 1        3.55       Tottenham         Everton       0.385              Y
# 2        2.77         Burnley         Burnley       0.577              N
# 3        2.17  Crystal Palace  Crystal Palace       0.385              N
# 4        1.79     Southampton     Southampton       0.427              N
# ..        ...             ...             ...         ...            ...
# 328      1.35     Inter Milan     Inter Milan       0.508              N
# 329      1.81           Genoa           Genoa       0.542              N
# 330      1.54        Sassuolo        Sassuolo       0.553              N
# 331      3.11        AC Milan        AC Milan       0.412              N
# 332      4.32          Torino          Torino       0.550              N
#
#        True_Result  Winner_Odd
# 0             Draw        3.70
# 1             Draw        3.40
# 2     Swansea City        2.82
# 3    West Bromwich        3.91
# 4             Draw        3.71
# ..             ...         ...
# 328       Cagliari        9.49
# 329           Draw        3.50
# 330       Sassuolo        1.54
# 331       AC Milan        2.55
# 332         Torino        1.92
#
# [333 rows x 12 columns]

# %%
League_count = len(Sibyl_vs_Bookies_df["League"].unique())


Confidence_min = Confidence_percent.min()
Confidence_max = Confidence_percent.max()

# %%
summary_df = pd.DataFrame({"League count": [League_count],
                              "Confidence min": Confidence_min,
                              "Confidence max": Confidence_max
                            })
summary_df
# Out:
#    League count  Confidence min  Confidence max
# 0             5            37.4            69.5

# %%
Confidence_percent = Sibyl_vs_Bookies_df["Confidence"]*100
Sibyl_vs_Bookies_df["Confidence_percent"] = Confidence_percent

Winner_Odd_percent = Sibyl_vs_Bookies_df["Winner_Odd"]*10
Sibyl_vs_Bookies_df["Winner_Odd_percent"] = Winner_Odd_percent

Sibyl_vs_Bookies_df
# Out:
#       ID          League        Date   Time                    Matchup_US_P  \
# 0      0         ligue-1  2016-08-12  19:30               Guingamp @ Monaco
# 1      1  premier-league  2016-08-13  15:00             Tottenham @ Everton
# 2      2  premier-league  2016-08-13  15:00          Swansea City @ Burnley
# 3      3  premier-league  2016-08-13  15:00  West Bromwich @ Crystal Palace
# 4      4  premier-league  2016-08-13  15:00           Watford @ Southampton
# ..   ...             ...         ...    ...                             ...
# 328  328         serie-a  2016-10-16  14:00          Cagliari @ Inter Milan
# 329  329         serie-a  2016-10-16  14:00                  Empoli @ Genoa
# 330  330         serie-a  2016-10-16  14:00              Crotone @ Sassuolo
# 331  331         serie-a  2016-10-16  19:45               AC Milan @ Chievo
# 332  332         serie-a  2016-10-17  19:45                Torino @ Palermo
#
#       Visitor_Team       Home_Team  Visitor_Odd  Draw_Odd  Home_Odd  \
# 0         Guingamp          Monaco         5.50      3.70      1.69
# 1        Tottenham         Everton         2.19      3.40      3.55
# 2     Swansea City         Burnley         2.82      3.15      2.77
# 3    West Bromwich  Crystal Palace         3.91      3.17      2.17
# 4          Watford     Southampton         4.86      3.71      1.79
# ..             ...             ...          ...       ...       ...
# 328       Cagliari     Inter Milan         9.49      5.14      1.35
# 329         Empoli           Genoa         4.95      3.50      1.81
# 330        Crotone        Sassuolo         6.73      4.15      1.54
# 331       AC Milan          Chievo         2.55      3.07      3.11
# 332         Torino         Palermo         1.92      3.46      4.32
#
#      Bookies_choice           Sibyl  Confidence Divergence_Y/N  Visi_Team_PTS  \
# 0            Monaco          Monaco       0.559              N              2
# 1         Tottenham         Everton       0.385              Y              1
# 2           Burnley         Burnley       0.577              N              1
# 3    Crystal Palace  Crystal Palace       0.385              N              1
# 4       Southampton     Southampton       0.427              N              1
# ..              ...             ...         ...            ...            ...
# 328     Inter Milan     Inter Milan       0.508              N              2
# 329           Genoa           Genoa       0.542              N              0
# 330        Sassuolo        Sassuolo       0.553              N              1
# 331        AC Milan        AC Milan       0.412              N              3
# 332          Torino          Torino       0.550              N              4
#
#      Home_Team_PTS    True_Result  Winner_Odd  Confidence_percent  \
# 0                2           Draw        3.70                55.9
# 1                1           Draw        3.40                38.5
# 2                0   Swansea City        2.82                57.7
# 3                0  West Bromwich        3.91                38.5
# 4                1           Draw        3.71                42.7
# ..             ...            ...         ...                 ...
# 328              1       Cagliari        9.49                50.8
# 329              0           Draw        3.50                54.2
# 330              2       Sassuolo        1.54                55.3
# 331              1       AC Milan        2.55                41.2
# 332              1         Torino        1.92                55.0
#
#      Winner_Odd_percent
# 0                  37.0
# 1                  34.0
# 2                  28.2
# 3                  39.1
# 4                  37.1
# ..                  ...
# 328                94.9
# 329                35.0
# 330                15.4
# 331                25.5
# 332                19.2
#
# [333 rows x 20 columns]

# %%
plt.bar(Sibyl_vs_Bookies_df['Confidence_percent'], Sibyl_vs_Bookies_df['Winner_Odd_percent'], color='r', alpha=1.0, align="center")
plt.title("Effect of Confidence to Winner_Odd")
plt.xlabel("Confidence")
plt.ylabel("Winner_Odd")
plt.xlim(0,80)
plt.figure(figsize=(50,5))
plt.show
plt.savefig('sportsbet_confidence.png')

# %%
Sibyl_vs_Bookies_df[["Confidence_percent", "Winner_Odd_percent"]].describe()
# Out:
#        Confidence_percent  Winner_Odd_percent
# count          333.000000          333.000000
# mean            50.960360           28.664264
# std              7.765861           20.880983
# min             37.400000           10.600000
# 25%             44.100000           17.500000
# 50%             50.900000           24.900000
# 75%             57.300000           33.500000
# max             69.500000          312.500000

# %%
Sibyl_vs_Bookies_df[["Confidence_percent", "Winner_Odd_percent"]].sem()
# Out:
# Confidence_percent    0.425567
# Winner_Odd_percent    1.144271
# dtype: float64
