# %%
# %run bookies_accuracy.ipynb

# %%
# %run sportbettingconfidencequestion.ipynb

# %%
# %run Home_TeamLoss.ipynb
# Out:
# The bookies' choice of the home team lost 102 times.
# The bookies' choice of the home team win 132 times.

# %%
# %run bettingdata.ipynb
# Out:
#  the correlation is -0.32770400095091795

# %%
# %run moving_odds.ipynb
